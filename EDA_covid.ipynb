# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedmoin44/EDA_Covid-19/blob/main/EDA_covid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-88ebf8c8-5089-4951-acb8-7bf17c39d890" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88ebf8c8-5089-4951-acb8-7bf17c39d890">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving owid-covid-data.csv to owid-covid-data.csv

# %%
#Reading csv file using pandas
df  = pd.read_csv('owid-covid-data.csv')
df.tail()
# Out:
#        iso_code continent  location      date  total_cases  new_cases  \
# 166321      ZWE    Africa  Zimbabwe  3/1/2022     236871.0      491.0
# 166322      ZWE    Africa  Zimbabwe  3/2/2022     237503.0      632.0
# 166323      ZWE    Africa  Zimbabwe  3/3/2022     237503.0        0.0
# 166324      ZWE    Africa  Zimbabwe  3/4/2022     238739.0     1236.0
# 166325      ZWE    Africa  Zimbabwe  3/5/2022     239019.0      280.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 166321             413.000        5395.0         0.0                1.000
# 166322             416.286        5396.0         1.0                1.143
# 166323             362.286        5396.0         0.0                0.857
# 166324             467.429        5397.0         1.0                0.714
# 166325             459.429        5397.0         0.0                0.571
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
#finding missing Values count
df.isna().sum()
# Out:
# iso_code                                        0
# continent                                    9956
# location                                        0
# date                                            0
# total_cases                                  3033
#                                             ...
# human_development_index                     30073
# excess_mortality_cumulative_absolute       160630
# excess_mortality_cumulative                160630
# excess_mortality                           160630
# excess_mortality_cumulative_per_million    160630
# Length: 67, dtype: int64

# %%
#Analysing data of india and china from the dataset
df_ind = df[df['location']=='India']
df_usa = df[df['location']=='United States']
df_chi = df[df['location']=='China']

# %%
#Considering 4 features 
df_ind_death_analysis = df_ind[['date','total_cases','new_cases','total_deaths','new_deaths']]

# %%
df_chi_death_analysis = df_ind[['date','total_cases','new_cases','total_deaths','new_deaths']]

# %%
df_usa_death_analysis = df_ind[['date','total_cases','new_cases','total_deaths','new_deaths']]

# %%
df_ind_death_analysis
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths
# 69678  1/30/2020          1.0        1.0           NaN         NaN
# 69679  1/31/2020          1.0        0.0           NaN         NaN
# 69680   2/1/2020          1.0        0.0           NaN         NaN
# 69681   2/2/2020          2.0        1.0           NaN         NaN
# 69682   2/3/2020          3.0        1.0           NaN         NaN
# ...          ...          ...        ...           ...         ...
# 70439   3/1/2022   42938599.0     7554.0      514246.0       223.0
# 70440   3/2/2022   42945160.0     6561.0      514388.0       142.0
# 70441   3/3/2022   42951556.0     6396.0      514589.0       201.0
# 70442   3/4/2022   42957477.0     5921.0      514878.0       289.0
# 70443   3/5/2022   42962953.0     5476.0      515036.0       158.0
#
# [766 rows x 5 columns]

# %%
df_chi.shape
# Out:
# (774, 67)

# %%
df_usa_death_analysis = df_usa[['date','total_cases','new_cases','total_deaths','new_deaths']]

# %%
df_usa_death_analysis.isna().sum()
# Out:
# date             0
# total_cases      0
# new_cases        1
# total_deaths    38
# new_deaths      38
# dtype: int64

# %%
df_usa_death_analysis[0:40]
# Out:
#              date  total_cases  new_cases  total_deaths  new_deaths
# 157222  1/22/2020          1.0        NaN           NaN         NaN
# 157223  1/23/2020          1.0        0.0           NaN         NaN
# 157224  1/24/2020          2.0        1.0           NaN         NaN
# 157225  1/25/2020          2.0        0.0           NaN         NaN
# 157226  1/26/2020          5.0        3.0           NaN         NaN
# 157227  1/27/2020          5.0        0.0           NaN         NaN
# 157228  1/28/2020          5.0        0.0           NaN         NaN
# 157229  1/29/2020          6.0        1.0           NaN         NaN
# 157230  1/30/2020          6.0        0.0           NaN         NaN
# 157231  1/31/2020          8.0        2.0           NaN         NaN
# 157232   2/1/2020          8.0        0.0           NaN         NaN
# 157233   2/2/2020          8.0        0.0           NaN         NaN
# 157234   2/3/2020         11.0        3.0           NaN         NaN
# ...

# %%
df_usa_death_analysis[['new_cases','total_deaths','new_deaths']]= df_usa_death_analysis[['new_cases','total_deaths','new_deaths']].fillna(0)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_usa_death_analysis.tail()
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths
# 157991  3/1/2022   79091361.0    47031.0      952423.0      1691.0
# 157992  3/2/2022   79143716.0    52355.0      954518.0      2095.0
# 157993  3/3/2022   79196008.0    52292.0      956261.0      1743.0
# 157994  3/4/2022   79250509.0    54501.0      958144.0      1883.0
# 157995  3/5/2022   79265726.0    15217.0      958437.0       293.0

# %%
      
total_deaths
# Out:
# date             0
# total_cases      0
# new_cases        1
# total_deaths    38
# new_deaths      38
# dtype: int64

# %%
#finding missing Values count
df_ind_death_analysis.isna().sum()
# Out:
# date             0
# total_cases      0
# new_cases        0
# total_deaths    41
# new_deaths      43
# dtype: int64

# %%
#finding missing Values count
df_chi_death_analysis.isna().sum()
# Out:
# date            0
# total_cases     0
# new_cases       3
# total_deaths    0
# new_deaths      3
# dtype: int64

# %%
#finding mean of total deaths
df_ind_death_analysis['total_deaths'].mean()
# Out:
# 235126.2248275862

# %%
#finding mode of total deaths
df_ind_death_analysis['total_deaths'].mode()
# Out:
# 0    2.0
# dtype: float64

# %%
#finding median of total deaths
df_ind_death_analysis['total_deaths'].median()
# Out:
# 157930.0

# %%
#finding na values row's in the dataset
df_ind_death_analysis[df_ind_death_analysis['total_deaths'].isna()]
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths
# 69678  1/30/2020          1.0        1.0           NaN         NaN
# 69679  1/31/2020          1.0        0.0           NaN         NaN
# 69680   2/1/2020          1.0        0.0           NaN         NaN
# 69681   2/2/2020          2.0        1.0           NaN         NaN
# 69682   2/3/2020          3.0        1.0           NaN         NaN
# 69683   2/4/2020          3.0        0.0           NaN         NaN
# 69684   2/5/2020          3.0        0.0           NaN         NaN
# 69685   2/6/2020          3.0        0.0           NaN         NaN
# 69686   2/7/2020          3.0        0.0           NaN         NaN
# 69687   2/8/2020          3.0        0.0           NaN         NaN
# 69688   2/9/2020          3.0        0.0           NaN         NaN
# 69689  2/10/2020          3.0        0.0           NaN         NaN
# 69690  2/11/2020          3.0        0.0           NaN         NaN
# ...

# %%
# after seeing the missing valus location it be good 
# to fill na values with zero's rather then mean or any other value 
df_ind_death_analysis[0:44]
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths
# 69678  1/30/2020          1.0        1.0           NaN         NaN
# 69679  1/31/2020          1.0        0.0           NaN         NaN
# 69680   2/1/2020          1.0        0.0           NaN         NaN
# 69681   2/2/2020          2.0        1.0           NaN         NaN
# 69682   2/3/2020          3.0        1.0           NaN         NaN
# 69683   2/4/2020          3.0        0.0           NaN         NaN
# 69684   2/5/2020          3.0        0.0           NaN         NaN
# 69685   2/6/2020          3.0        0.0           NaN         NaN
# 69686   2/7/2020          3.0        0.0           NaN         NaN
# 69687   2/8/2020          3.0        0.0           NaN         NaN
# 69688   2/9/2020          3.0        0.0           NaN         NaN
# 69689  2/10/2020          3.0        0.0           NaN         NaN
# 69690  2/11/2020          3.0        0.0           NaN         NaN
# ...

# %%
#Assing zero to the NA values for total death and new death columns
df_ind_death_analysis[['total_deaths','new_deaths']]= df_ind_death_analysis[['total_deaths','new_deaths']].fillna(0)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_ind_death_analysis
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths
# 69678  1/30/2020          1.0        1.0           0.0         0.0
# 69679  1/31/2020          1.0        0.0           0.0         0.0
# 69680   2/1/2020          1.0        0.0           0.0         0.0
# 69681   2/2/2020          2.0        1.0           0.0         0.0
# 69682   2/3/2020          3.0        1.0           0.0         0.0
# ...          ...          ...        ...           ...         ...
# 70439   3/1/2022   42938599.0     7554.0      514246.0       223.0
# 70440   3/2/2022   42945160.0     6561.0      514388.0       142.0
# 70441   3/3/2022   42951556.0     6396.0      514589.0       201.0
# 70442   3/4/2022   42957477.0     5921.0      514878.0       289.0
# 70443   3/5/2022   42962953.0     5476.0      515036.0       158.0
#
# [766 rows x 5 columns]

# %%
df_ind_death_analysis[0:44]
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths
# 69678  1/30/2020          1.0        1.0           0.0         0.0
# 69679  1/31/2020          1.0        0.0           0.0         0.0
# 69680   2/1/2020          1.0        0.0           0.0         0.0
# 69681   2/2/2020          2.0        1.0           0.0         0.0
# 69682   2/3/2020          3.0        1.0           0.0         0.0
# 69683   2/4/2020          3.0        0.0           0.0         0.0
# 69684   2/5/2020          3.0        0.0           0.0         0.0
# 69685   2/6/2020          3.0        0.0           0.0         0.0
# 69686   2/7/2020          3.0        0.0           0.0         0.0
# 69687   2/8/2020          3.0        0.0           0.0         0.0
# 69688   2/9/2020          3.0        0.0           0.0         0.0
# 69689  2/10/2020          3.0        0.0           0.0         0.0
# 69690  2/11/2020          3.0        0.0           0.0         0.0
# ...

# %%
#Since we have only 3 NA values hence those rows are droped
df_chi_death_analysis.dropna(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_chi_death_analysis.isna().sum()
# Out:
# total_cases     0
# new_cases       0
# total_deaths    0
# new_deaths      0
# dtype: int64

# %%
df_ind_death_analysis.isna().sum()
# Out:
# total_cases     0
# new_cases       0
# total_deaths    0
# new_deaths      0
# dtype: int64

# %%
df_ind_death_analysis.total_cases.sum()
# Out:
# 12874793738.0

# %%
df_ind_death_analysis.total_deaths.sum()
# Out:
# 170466513.0

# %%
 df_chi_death_analysis.total_cases.sum()
# Out:
# 67967051.0

# %%
df_chi_death_analysis.total_deaths.sum()
# Out:
# 3374043.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_ind_death_analysis.total_cases
# Out:
# 69678           1.0
# 69679           1.0
# 69680           1.0
# 69681           2.0
# 69682           3.0
#             ...
# 70439    42938599.0
# 70440    42945160.0
# 70441    42951556.0
# 70442    42957477.0
# 70443    42962953.0
# Name: total_cases, Length: 766, dtype: float64

# %%
import plotly.express as px

# %%
   def get_graph(df,a,b,c):
      fig = px.bar(df, x = a ,y = b ,title= c)
      return  fig.show()

# %%
 get_graph(df_ind_death_analysis,'date','total_cases','Covid-19 total cases in INDIA')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
 get_graph(df_ind_death_analysis,'date','new_cases','Covid-19 New cases per day in INDIA')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
 get_graph(df_ind_death_analysis,'date','total_deaths','Covid-19 Total Deaths in INDIA')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
 get_graph(df_ind_death_analysis,'date','new_deaths','Covid-19 Deaths per Day in INDIA')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
 get_graph(df_chi_death_analysis,'date','total_cases',' Total Covid-19 cases in CHINA')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
 get_graph(df_chi_death_analysis,'date','total_deaths','Covid-19 cases per day in CHINA')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
 get_graph(df_usa_death_analysis,'date','new_cases','Covid-19 per day cases in USA')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
 get_graph(df_usa_death_analysis,'date','total_cases','total Covid-19 cases in USA')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
 get_graph(df_usa_death_analysis,'date','new_deaths','Covid-19 per day deaths in USA')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
 get_graph(df_usa_death_analysis,'date','total_deaths','Covid-19 per day deaths in USA')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
